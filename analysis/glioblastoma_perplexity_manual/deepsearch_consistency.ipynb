# %% [markdown]
# # DeepSearch Consistency and GO Coverage Analysis
#
# This notebook summarizes run-to-run stability of DeepSearch gene programs and how those programs align with GO enrichment results provided in the `Comparisons/` folder.

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')
PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'geneset_folder_mapping.csv').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
DATA_DIR = PROJECT_ROOT / 'data'

# %% [markdown]
# ## Run-to-run gene program consistency

# %%
matches = pd.read_csv(DATA_DIR / 'deepsearch_program_matches.csv')
runs = pd.read_csv(DATA_DIR / 'deepsearch_runs.csv')
unmatched_programs = pd.read_csv(DATA_DIR / 'deepsearch_unmatched_programs.csv')

match_summary = (
    matches.groupby(['metamodule', 'annotation', 'folder'])
    .agg(
        avg_similarity=('combined_similarity', 'mean'),
        median_similarity=('combined_similarity', 'median'),
        avg_gene_jaccard=('gene_jaccard', 'mean'),
        avg_name_similarity=('name_similarity', 'mean'),
        matched_pairs=('combined_similarity', 'size')
    )
    .reset_index()
)

run_counts = (
    runs.groupby(['metamodule', 'annotation', 'folder'])
    .agg(total_programs=('program_count', 'sum'))
    .reset_index()
)

unmatched_counts = (
    unmatched_programs.groupby(['metamodule', 'annotation', 'folder'])
    .size()
    .reset_index(name='unmatched_programs')
)

consistency = (
    match_summary
    .merge(run_counts, on=['metamodule', 'annotation', 'folder'])
    .merge(unmatched_counts, on=['metamodule', 'annotation', 'folder'])
)
consistency['matched_fraction'] = (consistency['matched_pairs'] * 2) / consistency['total_programs']
consistency['unmatched_fraction'] = consistency['unmatched_programs'] / consistency['total_programs']
consistency = consistency.sort_values('avg_similarity', ascending=False)
consistency
# Out:
#     metamodule           annotation                  folder  avg_similarity  \
# 9            9      Proliferative 2      09_Proliferative_2        0.543254
# 0            0              Gliosis              00_Gliosis        0.528247
# 4            4    AC-gliosis-like 1    04_AC-gliosis-like_1        0.460967
# 1            1        OPC-AC-like 1        01_OPC-AC-like_1        0.439815
# 2            2  NPC-neuronal-like 1  02_NPC-neuronal-like_1        0.429684
# 12          13           OPC-like 2           13_OPC-like_2        0.377671
# 8            8      Gliosis-hypoxia      08_Gliosis-hypoxia        0.361888
# 3            3  NPC-neuronal-like 2  03_NPC-neuronal-like_2        0.343056
# 11          11           OPC-like 1           11_OPC-like_1        0.301557
# 10          10    AC-gliosis-like 2    10_AC-gliosis-like_2        0.284732
# 7            7        Proliferative        07_Proliferative        0.248616
# 6            6         OPC-NPC-like         06_OPC-NPC-like        0.246429
# 5            5     AC-neuronal-like     05_AC-neuronal-like        0.218750
#
#     median_similarity  avg_gene_jaccard  avg_name_similarity  matched_pairs  \
# 9            0.523413          0.519841             0.566667              4
# 0            0.444886          0.560065             0.496429              4
# 4            0.534091          0.572727             0.349206              6
# 1            0.361111          0.500000             0.379630              3
# 2            0.419255          0.597464             0.261905              5
# 12           0.395833          0.533120             0.222222              3
# 8            0.265152          0.297850             0.425926              3
# 3            0.312500          0.444444             0.241667              3
# 11           0.335227          0.436448             0.166667              3
# 10           0.310606          0.313908             0.255556              3
# 7            0.187500          0.288899             0.208333              3
# 6            0.246429          0.350000             0.142857              2
# 5            0.233333          0.315278             0.122222              3
#
#     total_programs  unmatched_programs  matched_fraction  unmatched_fraction
# 9                9                   1          0.888889            0.111111
# 0                9                   1          0.888889            0.111111
# 4               13                   1          0.923077            0.076923
# 1                9                   3          0.666667            0.333333
# 2               13                   3          0.769231            0.230769
# 12              14                   8          0.428571            0.571429
# 8                9                   3          0.666667            0.333333
# 3                8                   2          0.750000            0.250000
# 11              14                   8          0.428571            0.571429
# 10               8                   2          0.750000            0.250000
# 7               14                   8          0.428571            0.571429
# 6               11                   7          0.363636            0.636364
# 5                8                   2          0.750000            0.250000

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(consistency['annotation'], consistency['avg_similarity'], color='#4C72B0')
ax.set_ylabel('Average combined similarity (genes + names)')
ax.set_xlabel('Gene set annotation')
ax.set_title('Run-to-run similarity per gene set')
ax.set_ylim(0, 1)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Run-to-run similarity uses a weighted score (0.6 gene-set Jaccard + 0.4 text similarity). Even when similarity is high, unmatched program fractions highlight how stochasticity introduces novel programs per run.

# %% [markdown]
# ## GO enrichment coverage from comparison reports

# %%
comparison_summary = pd.read_csv(DATA_DIR / 'comparison_summary.csv')
mapping = pd.read_csv(PROJECT_ROOT / 'geneset_folder_mapping.csv')
all_sets = mapping[['metamodule', 'annotation', 'new_folder']].rename(columns={'new_folder': 'folder'})
missing_sets = all_sets[~all_sets['metamodule'].isin(comparison_summary['metamodule'])]
comparison_summary['go_match_pct'] = comparison_summary['matched_go_terms_estimated'] / comparison_summary['total_gsea_terms'] * 100
comparison_summary['go_unmatched_pct'] = comparison_summary['unmatched_go_terms_reported'] / comparison_summary['total_gsea_terms'] * 100
comparison_summary = comparison_summary.sort_values('go_match_pct', ascending=False)
comparison_summary
# Out:
#     metamodule           annotation                  folder  \
# 1           10    AC-gliosis-like 2    10_AC-gliosis-like_2
# 2           12  NPC-neuronal-like 3  12_NPC-neuronal-like_3
# 3           13           OPC-like 2           13_OPC-like_2
# 4            1        OPC-AC-like 1        01_OPC-AC-like_1
# 5            2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 6            3  NPC-neuronal-like 2  03_NPC-neuronal-like_2
# 7            4    AC-gliosis-like 1    04_AC-gliosis-like_1
# 8            5     AC-neuronal-like     05_AC-neuronal-like
# 9            6         OPC-NPC-like         06_OPC-NPC-like
# 10           7        Proliferative        07_Proliferative
# 0            9      Proliferative 2      09_Proliferative_2
#
#                  source_file  total_gsea_terms  unmatched_go_terms_reported  \
# 1   comparison geneset_11.md                25                            0
# 2   comparison geneset_13.md                14                            0
# 3   comparison geneset_14.md                22                            0
# 4    comparison geneset_2.md                 1                            0
# 5    comparison geneset_3.md                15                            0
# 6    comparison geneset_4.md                 8                            0
# 7    comparison geneset_5.md                11                            0
# 8    comparison geneset_6.md                 3                            0
# 9    comparison geneset_7.md                24                            0
# 10   comparison geneset_8.md               156                            0
# 0   comparison geneset_10.md               128                           30
#
#     unmatched_go_terms_listed  matched_go_terms_estimated  programs_total  \
# 1                           0                          25               5
# 2                           0                          14               5
# 3                           0                          22              12
# 4                           0                           1               4
# 5                           0                          15               9
# 6                           0                           8               3
# 7                           0                          11               7
# 8                           0                           3               4
# 9                           0                          24               5
# 10                          0                         156               3
# 0                           0                          98               5
#
#     programs_without_go_match  go_match_pct  go_unmatched_pct
# 1                           0      100.0000            0.0000
# 2                           1      100.0000            0.0000
# 3                           5      100.0000            0.0000
# 4                           3      100.0000            0.0000
# 5                           6      100.0000            0.0000
# 6                           1      100.0000            0.0000
# 7                           4      100.0000            0.0000
# 8                           2      100.0000            0.0000
# 9                           4      100.0000            0.0000
# 10                          0      100.0000            0.0000
# 0                           0       76.5625           23.4375

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(comparison_summary['annotation'], comparison_summary['go_match_pct'], color='#55A868')
ax.set_ylabel('% GO terms matched')
ax.set_xlabel('Gene set annotation')
ax.set_title('GO coverage reported in comparison files')
ax.set_ylim(0, 110)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

if not missing_sets.empty:
    display(missing_sets)
# Out:
#     metamodule       annotation              folder
# 0            0          Gliosis          00_Gliosis
# 8            8  Gliosis-hypoxia  08_Gliosis-hypoxia
# 11          11       OPC-like 1       11_OPC-like_1
# 14          14    OPC-AC-like 2    14_OPC-AC-like_2

# %% [markdown]
# Gene set `geneset_9` (metamodule 8) lacks a comparison table, so it is excluded from the coverage stats above.

# %% [markdown]
# ## Novel gene programs without GO counterparts

# %%
novel_programs = pd.read_csv(DATA_DIR / 'comparison_novel_programs.csv')
program_catalog = pd.read_csv(DATA_DIR / 'deepsearch_programs.csv')
run1_catalog = program_catalog[program_catalog['run_index'] == 1][['folder', 'program_name', 'supporting_gene_count']]
novel_programs = novel_programs.merge(run1_catalog, on=['folder', 'program_name'], how='left', suffixes=('', '_run_data'))
novel_programs['supporting_gene_count'] = novel_programs['supporting_gene_count'].fillna(novel_programs['supporting_gene_count_run_data'])
novel_ranked = novel_programs.sort_values(['supporting_gene_count', 'annotation'], ascending=[False, True])
novel_ranked.head(20)
# Out:
#     metamodule           annotation                  folder  \
# 1           13           OPC-like 2           13_OPC-like_2
# 15           3  NPC-neuronal-like 2  03_NPC-neuronal-like_2
# 10           2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 2           13           OPC-like 2           13_OPC-like_2
# 20           5     AC-neuronal-like     05_AC-neuronal-like
# 4           13           OPC-like 2           13_OPC-like_2
# 16           4    AC-gliosis-like 1    04_AC-gliosis-like_1
# 9            2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 11           2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 22           6         OPC-NPC-like         06_OPC-NPC-like
# 3           13           OPC-like 2           13_OPC-like_2
# 17           4    AC-gliosis-like 1    04_AC-gliosis-like_1
# 13           2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 14           2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 6            1        OPC-AC-like 1        01_OPC-AC-like_1
# 5           13           OPC-like 2           13_OPC-like_2
# 12           2  NPC-neuronal-like 1  02_NPC-neuronal-like_1
# 7            1        OPC-AC-like 1        01_OPC-AC-like_1
# 24           6         OPC-NPC-like         06_OPC-NPC-like
# 25           6         OPC-NPC-like         06_OPC-NPC-like
#
#                  source_file  \
# 1   comparison geneset_14.md
# 15   comparison geneset_4.md
# 10   comparison geneset_3.md
# 2   comparison geneset_14.md
# 20   comparison geneset_6.md
# 4   comparison geneset_14.md
# 16   comparison geneset_5.md
# 9    comparison geneset_3.md
# 11   comparison geneset_3.md
# 22   comparison geneset_7.md
# 3   comparison geneset_14.md
# 17   comparison geneset_5.md
# 13   comparison geneset_3.md
# 14   comparison geneset_3.md
# 6    comparison geneset_2.md
# 5   comparison geneset_14.md
# 12   comparison geneset_3.md
# 7    comparison geneset_2.md
# 24   comparison geneset_7.md
# 25   comparison geneset_7.md
#
#                                          program_name  supporting_gene_count  \
# 1            Lipid Metabolism and Membrane Remodeling                   12.0
# 15  Glioma Stem Cell Maintenance and Therapy Resis...                    8.0
# 10  Transcriptional Regulation and Chromatin Remod...                    7.0
# 2           Hypoxia Response and Angiogenic Signaling                    7.0
# 20                    Glioblastoma Immune Suppression                    6.0
# 4        Amino Acid Metabolism and Nutrient Transport                    6.0
# 16               Angiogenesis and Vascular Remodeling                    5.0
# 9                         GABAergic Neurotransmission                    5.0
# 11                 cAMP Signaling and Kinase Cascades                    4.0
# 22                   Sonic Hedgehog and GLI Signaling                    4.0
# 3                 Autophagy and Lysosomal Degradation                    4.0
# 17        Immunomodulation, Hypoxia, and Inflammation                    3.0
# 13                        Solute Carrier Transporters                    3.0
# 14                                Immune Cell Markers                    3.0
# 6   Glial/astrocyte differentiation and tumor plas...                    3.0
# 5           DNA Damage Response and Genomic Stability                    3.0
# 12                           Neuregulin-BMP Signaling                    2.0
# 7                    Redox and ferroptosis resistance                    2.0
# 24                         EGFR/ERBB Family Signaling                    2.0
# 25                                  Immunosuppression                    2.0
#
#     supporting_gene_count_run_data
# 1                              NaN
# 15                             NaN
# 10                             7.0
# 2                              NaN
# 20                             6.0
# 4                              NaN
# 16                             NaN
# 9                              5.0
# 11                             4.0
# 22                             4.0
# 3                              NaN
# 17                             NaN
# 13                             3.0
# 14                             3.0
# 6                              3.0
# 5                              NaN
# 12                             2.0
# 7                              2.0
# 24                             2.0
# 25                             2.0

# %% [markdown]
# The table ranks unmatched programs by the number of supporting genes reported in the DeepSearch output (run 1 for each gene set).

# %% [markdown]
# ## Gene-set overlap heatmaps
#
# Run-to-run gene overlap (Jaccard) matrices with overlap counts are saved to `analysis/confusion_heatmaps`.

# %%
from scripts.generate_heatmaps import Path as _Path
from scripts.generate_heatmaps import DATA_DIR as HEATMAP_DATA_DIR
print('Heatmaps saved to analysis/confusion_heatmaps. Rerun scripts/generate_heatmaps.py after installing matplotlib.')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from scripts.generate_heatmaps import Path as _Path
#       2 from scripts.generate_heatmaps import DATA_DIR as HEATMAP_DATA_DIR
#       3 print('Heatmaps saved to analysis/confusion_heatmaps. Rerun scripts/generate_heatmaps.py after installing matplotlib.')
#
# ModuleNotFoundError: No module named 'scripts'

# %% [markdown]
# ## Gene-set overlap heatmaps
#
# The confusion matrices above are also available as color-coded heatmaps (Jaccard value + overlap/run gene counts) written to `analysis/confusion_heatmaps`.

# %%
# Generate heatmaps (requires matplotlib installed in the current kernel)
from scripts import generate_heatmaps
print(f'Heatmaps saved under {generate_heatmaps.OUTPUT_DIR}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Generate heatmaps (requires matplotlib installed in the current kernel)
# ----> 2 from scripts import generate_heatmaps
#       3 print(f'Heatmaps saved under {generate_heatmaps.OUTPUT_DIR}')
#
# ModuleNotFoundError: No module named 'scripts'

# %%
# Generate bubble visuals (requires matplotlib installed in the current kernel)
from scripts import generate_heatmaps
print(f'Bubble + key plots saved under {generate_heatmaps.OUTPUT_DIR}')
